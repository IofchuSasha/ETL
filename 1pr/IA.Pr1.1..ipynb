# %% [markdown]
# Вариант 16. В соответствии со списком. Тема 16.   Обучающие курсы от Мосбиржи. Там же полезные сервисы в помощь инвесторам — https://red-circule.com/

# %%
import requests
from bs4 import BeautifulSoup as bso
# Импорт стандартных пакетов
import pandas as pd

# Для парсинга веб-страниц
import requests as reqs
import urllib.request
from bs4 import BeautifulSoup
import json
import os
import pprint

# Для выполнения операций с регулярными выражениями
import re
# URL веб-сайта
url = 'https://red-circule.com/'

# Отправка GET-запроса к веб-сайту
response = requests.get(url)

# Проверка успешности запроса
if response.status_code == 200:
    # Использование BeautifulSoup для парсинга HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    
    
    headlines = soup.find_all('h2', class_='post-title')
    for headline in headlines:
        print(headline.text.strip())
else:
    print('Ошибка при получении данных:', response.status_code)

# %%
response
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# ...

# %%
print(soup.title)
# Out:
# <title data-react-helmet="true">Красный Циркуль учит принимать финансовые решения: обучение финансам, онлайн трейдингу на бирже и инвестициям в фондовый рынок</title>
